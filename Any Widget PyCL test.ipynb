# %% [markdown]
# # Anywidget demonstration
#
# This is a jupyter notebook with a WebGPU based anywidget in the first cell.

# %%
import pathlib
import anywidget
import traitlets

from IPython.display import HTML, display
html_code = "<h1>Hello, world!</h1><p>This is a paragraph.</p>"
install_div_space = \
"""<div id="gl_div" name="gl_div"> <div>"""
display(HTML(install_div_space))

class glwidget(anywidget.AnyWidget):
    _esm = "./outwidget/static/widget_index.js"
    ##_css = pathlib.Path(__file__).parent / "index.css"
    value = traitlets.Int(0).tag(sync=True)

glwidget()
# Out:
# <div id="gl_div" name="gl_div"> <div>
# glwidget()

# %%
(3.27**2 + 1.65**2 + 3.41**2)
